# %% [markdown]
# ### Import the dataset (from 24th April 2022 to 17 May 2022)

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
plt.rcParams['figure.figsize'] = (15, 9)
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('curved_labelled_data.csv')
df[['time']] = df[['time']].apply(pd.to_datetime)
df.rename(columns = {'Unnamed: 0':'x_column' }, inplace = True)

# %% [markdown]
# ### Plotting the dataset

# %%
plt.rcParams['figure.figsize'] = (12, 9)
fig, ax = plt.subplots(1,1)
fig.patch.set_facecolor('white')
ax.scatter(df['time'],df['height'], c= df['data_label'], cmap='rainbow')
ax.grid(color = 'gray', linestyle = '--', linewidth = 0.8)
ax.set_title('Outliers and the main trend from 24th April to 17th May 2022', fontsize=18, weight='bold')
ax.set_xlabel('Time', fontsize=18, weight = 'bold')
ax.set_ylabel('Water level (m)', fontsize=18, weight = 'bold')
ax.set_xlim(['2022-04-24 00:00:00'],['2022-05-17 23:59:59'])
ax.set_ylim(0, 1.9)
ax.set_xticklabels(df['time'], fontsize=16, weight='bold')
ax.tick_params(axis='y', labelsize=16)
ax.tick_params(axis='x',which='major', labelsize=16)

## Define the date format
date_form = DateFormatter("%d-%m")
ax.xaxis.set_major_formatter(date_form)
ax.set(facecolor = "white")

plt.savefig('sample_photo_curved.png', dpi=450, orientation='portrait', bbox_inches='tight', facecolor='w',edgecolor='b',)
plt.show()

# %% [markdown]
# ### OneClassSVM
# - HPER-PLANE estimation

# %%
from sklearn.svm import OneClassSVM
import datetime as datetime
import numpy as np
water_level = np.array(df['height'])

# %% [markdown]
# ### Anomaly detection

# %%
length = np.array(df.height)
water_arrays = np.array_split(length, 11)

# %% [markdown]
# ### OneClassSVM water level data fitting

# %%
sup_list = []
for array in water_arrays:
    SVM_labels = OneClassSVM(kernel= 'linear', gamma='scale', nu=0.948).fit_predict(array.reshape(-1, 1))
    sup_list.append(SVM_labels)
#print(sup_list)

# %%
l = []
for i in sup_list:
    for ii in i.tolist():
        l.append(ii)        
len(l)
# Out:
# 6712

# %%
SVM_labels = l
df['SVM_labels'] = SVM_labels
df.to_csv ('OneClassSVM_output_curved.csv', header=True,index = False)

# %%
SVM_list = list(df['SVM_labels'])
clusters =[]
for i in SVM_list:
    if i == -1:
        cluster = 0
    else:
        cluster = 1
    clusters.append(cluster) 
    p = clusters

# %%
df['SVM_labels'] = p

# %%
df.to_csv ('SVM_output_metric_curved.csv', header=True,index = False)

# %%
temp_df = df.loc[(df['SVM_labels'] == 0)]
df3 = temp_df.set_index('time')
df4 = df3.reset_index()

# %%
temp_df1 = df.loc[(df['SVM_labels'] == 1)]
df5 = temp_df1.set_index('time')
df6 = df5.reset_index()

# %%
plt.rcParams['figure.figsize'] = (10, 7)
fig, ax = plt.subplots(1,1)
fig.patch.set_facecolor('white')
Normal = ax.scatter(df4['time'],df4['height'], c ="black", marker="o", s = 10**1.35)
Outlier = ax.scatter(df6['time'],df6['height'], c ="red",marker ="o", s = 10**1.35)
ax.grid(color = 'gray', linestyle = '--', linewidth = 1.3)
ax.set_title('OneClassSVM classification output for the non-uniform data', fontsize=18, weight='bold')
ax.set_xlabel('Time', fontsize=18, weight = 'bold')
ax.set_ylabel('Water level (m)', fontsize=18, weight = 'bold')
ax.set_xlim(['2022-04-26 00:00:01'],['2022-05-17 23:59:59'])
ax.set_ylim(0,1.9)
ax.set_xticklabels(df['time'], fontsize=16, weight='bold')
ax.tick_params(axis='y', labelsize=16)
ax.tick_params(axis='x',which='major', labelsize=16)

## Define the date format
date_form = DateFormatter("%d-%m")
ax.xaxis.set_major_formatter(date_form)
ax.legend(["Normal", "Outlier"], loc ="upper left", fancybox=True,facecolor='#01FFFF',prop={'size': 15,  'style': 'normal'})
ax.set(facecolor = "white")
plt.savefig('oneclass_curved.png', dpi=450, orientation='portrait', bbox_inches='tight', facecolor='w',edgecolor='b',)
plt.show()

# %% [markdown]
# ### Model metrics

# %%
from sklearn.metrics import accuracy_score,f1_score, precision_score, recall_score, confusion_matrix, roc_curve, auc, ConfusionMatrixDisplay
data_labels = list(df['data_label'])
SVM_labels = list(df['SVM_labels'])

# %%
c_matrix = confusion_matrix (data_labels,SVM_labels)
disp = ConfusionMatrixDisplay(c_matrix )
disp.plot(cmap=plt.cm.Blues,values_format='g',)
plt.xlabel('Predicted label', weight = 'bold')
plt.ylabel('True Label', weight = 'bold')


plt.savefig('con_curved.png', dpi=450, orientation='portrait', bbox_inches='tight', facecolor='w',edgecolor='b',)
plt.show()

# %%
data_accuracy = accuracy_score (data_labels,SVM_labels)
data_accuracy
# Out:
# 0.9529201430274136

# %%
data_precision = precision_score (data_labels,SVM_labels)
data_precision
# Out:
# 0.2849740932642487

# %%
data_recall_score = recall_score (data_labels,SVM_labels)
data_recall_score
# Out:
# 0.7333333333333333

# %%
data_f1_score = f1_score (data_labels,SVM_labels)
data_f1_score
# Out:
# 0.4104477611940298
