# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.dates import DateFormatter
import warnings
warnings. filterwarnings('ignore')
plt.rcParams['figure.figsize'] = (9,6)
from mlp_utility import set_global_determinism
set_global_determinism()

# %% [markdown]
# ## Forecasting using the stations only (MLP)
# #### Varying the Future steps
# - Vary the number of steps to the future
# - **Function** = stations_main(future_steps desired)

# %%
from mlp_utility import stations_main
from mlp_utility import optimal_window_stations
pred_plot = stations_main(1) # Desired number of future steps. 
pred_plot
# Out:
# RMSE:  0.046773356605993514

# %%
r2_plot = optimal_window_stations(1) # Desired number of future steps. 
r2_plot

# %% [markdown]
# ## Forecasting using the stations+water only
# #### Varying the Future steps
# - Vary the number of steps to the future
# - **Function** = stations_water_main(desired_future_step)

# %%
from mlp_utility import stations_water_main
from mlp_utility import optimal_window_stations_water
pred_plot2 = stations_water_main(3) # Desired number of future steps. 
pred_plot2
# Out:
# RMSE:  0.06700508877929279

# %%
mape_plot = optimal_window_stations_water(3) # Desired number of future steps. 
mape_plot
