# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.dates import DateFormatter
import warnings
warnings. filterwarnings('ignore')
plt.rcParams['figure.figsize'] = (9,6)
from lstm_utility import set_global_determinism
set_global_determinism()

# %% [markdown]
# ## Forecasting using the stations only (LSTM)

# %% [markdown]
# #### Varying the Future steps
# - Vary the number of steps to the future
# - **Function** = stations_main(future_steps desired)

# %%
warnings. filterwarnings('ignore')
from lstm_utility import stations_main
from lstm_utility import optimal_window_stations
pred_plot = stations_main(2) # Desired number of future steps. 
pred_plot

# %%
r2_plot = optimal_window_stations(2) # Desired number of future steps. 
r2_plot

# %% [markdown]
# ## Forecasting using the stations+water only
# #### Varying the Future steps
# - Vary the number of steps to the future
# - **Function** = stations_water_main(desired_future_step)

# %%
from lstm_utility import stations_water_main
from lstm_utility import optimal_window_stations_water
pred_plot2 = stations_water_main(1) # Desired number of future steps. 
pred_plot2
# Out:
# RMSE:  0.0554335503752407

# %%
mape_plot = optimal_window_stations_water(1) # Desired number of future steps. 
mape_plot
