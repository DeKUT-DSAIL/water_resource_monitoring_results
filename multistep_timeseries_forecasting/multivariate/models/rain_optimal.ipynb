# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from model_support import normalize
from model_support import set_global_determinism
from numpy.random import seed
import tensorflow as tf
tf.random.set_seed(0) 
seed(0)
set_global_determinism()

# %%
series1 =  pd.read_csv('original_set_raw.csv')
series2=  pd.read_csv('original_set_raw+water.csv')

# %%
from model_support import rain_main
output = rain_main(series1,'mlp',5)
# Out:
# optimal_window_size: 1

# %%
from model_support import rain_main_water
output2 = rain_main_water(series2,'x_boost',5)
# Out:
# optimal_window_size: 3
