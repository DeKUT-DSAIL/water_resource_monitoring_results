# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from baseline_support import normalize
from baseline_support import set_global_determinism
from numpy.random import seed
import tensorflow as tf
tf.random.set_seed(0) 
seed(0)
set_global_determinism()

# %%
from baseline_support import water_main
series = pd.read_csv('sensor6_2021.csv')
output = water_main(series,'av_baseline',5)
# Out:
# optimal_window_size: 3
